# %% [markdown]
# #Statistics Basics

# %% [markdown]
# #Q1.What is statistics, and why is it important?
#
# - Statistics is the branch of mathematics that deals with collecting, organizing, analyzing, and interpreting data.
# It helps us make decisions based on data.
#
# #Example:
#
#  A company uses statistics to understand customer preferences and improve products.
#
#
# #Q2.What are the two main types of statistics?
#
#  - Descriptive Statistics: Summarizes data (mean, median, etc.).
#
#  - Inferential Statistics: Makes predictions or generalizations about a population based on a sample.
#
#
# #Q3.What are descriptive statistics?
#
#  Descriptive statistics describe and summarize data using numbers like mean, median, mode, etc.
#
#  #Example:
#      Average score of a class in a test.
#
#
# #Q4.What is inferential statistics?
#
#  - Inferential statistics use data from a sample to make conclusions about a larger population.
#
#  #Example:
# Surveying 100 people to predict election results for an entire country.
#
#
# #Q5.hat is sampling in statistics?
#
#  - Sampling is selecting a subset of individuals from a population to estimate characteristics of the whole group.
#
#  #Example:
# Choosing 50 students from a school to find out the average study time.
#
#
# #Q5.What are the different types of sampling methods?
#
# - Random Sampling (Equal chance)
#
# - Systematic Sampling (Every k-th element)
#
# - Stratified Sampling (Dividing population into groups and sampling)
#
# - Cluster Sampling (Dividing into clusters and randomly choosing clusters)
#
#
# #Q7.What is the difference between random and non-random sampling?
#
# - Random Sampling: Every individual has an equal chance.
#
# - Non-random Sampling: Some bias or personal choice is involved.
#
# #Example:
# Random: Lottery draw.
#
# Non-random: Interviewing only your friends.
#
#
# #Q8.Define and give examples of qualitative and quantitative data.
# - Qualitative Data: Non-numeric, like colors or names.
# #Example: Gender, color of cars.
#
# - Quantitative Data: Numeric data.
# #Example: Age, height, income.
#
#
# #Q9.What are the different types of data in statistics?
# - Nominal Data (Names)
#
# - Ordinal Data (Order)
#
# - Interval Data (No true zero)
#
# - Ratio Data (True zero)
#
#
# #Q10.Explain nominal, ordinal, interval, and ratio levels of measurement.
#
# - Nominal: Categories only (e.g., Gender, City name)
#
# - Ordinal: Ordered categories (e.g., Ranking 1st, 2nd, 3rd)
#
# - Interval: Numeric, but no true zero (e.g., Temperature in Celsius)
#
# - Ratio: Numeric with true zero (e.g., Height, Weight)
#
#
#
# #Q11.What is the measure of central tendency?
#
# - It shows the center of a data set: mean, median, and mode.
#
#
# #Q12.Define mean, median, and mode.
#
# - Mean: Average (Sum of values ÷ Number of values)
#
# - Median: Middle value when sorted
#
# - Mode: Most frequent value
#
# #Q13.What is the significance of the measure of central tendency?
#
# - It helps to understand the "typical" value in a dataset.
#
#  #Example:
# The average salary helps understand income level.
#
#
# #Q14.What is variance, and how is it calculated?
#
# - Variance measures how far data points are from the mean.
#
# Formula:
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Q15.What is standard deviation, and why is it important?
#
# - Standard deviation is the square root of variance. It shows the spread of data.
#
# #Importance:
# A small standard deviation = data is close to mean,
# A large standard deviation = data is spread out.
#
#
# #Q16.Define and explain the term range in statistics.
#
# - Range = Maximum value - Minimum value
#
#  #Example:
# If highest score = 90, lowest = 40, then range = 90 - 40 = 50.
#
#
# #Q17.What is the difference between variance and standard deviation?
#
# - Variance is in squared units.
#
# - Standard Deviation is in original units (square root of variance).
#
#
# #Q18.What is skewness in a dataset?
#
# - Skewness measures the asymmetry of a distribution.
#
#
#
# #Q19.What does it mean if a dataset is positively or negatively skewed?
#
# - Positively Skewed: Tail on the right (more low values)
#
# - Negatively Skewed: Tail on the left (more high values)
#
#
# #Q20.Define and explain kurtosis.
#
# - Kurtosis measures the "peakedness" of a distribution.
#
# - High kurtosis: sharp peak
#
# - Low kurtosis: flat peak
#
#
# #Q21.What is the purpose of covariance?
#
# - Covariance shows how two variables change together.
#
# (A). Positive covariance: Variables move in same direction.
#
# (B). Negative covariance: Variables move in opposite directions.
#
#
#
# #Q22.What does correlation measure in statistics?
#
# - Correlation measures both the strength and direction of a relationship between two variables.
#
# Range: -1 to +1.
#
# #Q23.What is the difference between covariance and correlation?
#
# - Covariance: Only direction (+/-)
#
# - Correlation: Direction + strength (standardized between -1 and +1)
#
#
#
# #Q24.What are some real-world applications of statistics?
#
# - Medicine (clinical trials)
#
# - Business (market research)
#
# - Sports (player performance analysis)
#
# - Government (census)

# %% [markdown]
# #Practical Questions

# %%
#Q!.How do you calculate the mean, median, and mode of a dataset?
'''
import statistics

data = [10, 20, 20, 30, 40]

mean = statistics.mean(data)
median = statistics.median(data)
mode = statistics.mode(data)

print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)

✅Output>>>
Mean: 24
Median: 20
Mode: 20
'''

# %%
#Q2.Write a Python program to compute the variance and standard deviation of a dataset.
'''
import statistics

data = [10, 20, 30, 40, 50]

variance = statistics.variance(data)
std_dev = statistics.stdev(data)

print("Variance:", variance)
print("Standard Deviation:", std_dev)

✅Output>>>
Variance: 250
Standard Deviation: 15.811388300841896
'''

# %%
#Q3.Create a dataset and classify it into nominal, ordinal, interval, and ratio types.
'''
dataset = {
    "Nominal": ["Red", "Blue", "Green"],
    "Ordinal": ["Poor", "Average", "Good", "Excellent"],
    "Interval": [10, 20, 30],   # Temperature (no true zero)
    "Ratio": [5, 10, 15, 20]    # Height, Weight
}

print(dataset)
'''

# %%
#Q4.Implement sampling techniques like random sampling and stratified sampling.
'''
import random
import pandas as pd

# Random Sampling
data = list(range(1, 101))
random_sample = random.sample(data, 10)
print("Random Sample:", random_sample)

# Stratified Sampling
df = pd.DataFrame({
    'Gender': ['Male', 'Female']*50,
    'Score': random.choices(range(0,100), k=100)
})

stratified_sample = df.groupby('Gender', group_keys=False).apply(lambda x: x.sample(5))
print(stratified_sample)
'''

# %%
#Q5.Write a Python function to calculate the range of a dataset.
'''
def calculate_range(data):
    return max(data) - min(data)

data = [5, 10, 15, 20, 25]
print("Range:", calculate_range(data))

✅Output>>>
Range: 20
'''

# %%
#Q6.Create a dataset and plot its histogram to visualize skewness.
'''
import matplotlib.pyplot as plt

data = [10, 20, 20, 30, 40, 50, 60, 80, 100]

plt.hist(data, bins=5, edgecolor='black')
plt.title('Histogram')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()
'''

# %%
#Q7.Calculate skewness and kurtosis of a dataset using Python libraries.
'''
from scipy.stats import skew, kurtosis

data = [10, 20, 20, 30, 40, 50, 60, 80, 100]

print("Skewness:", skew(data))
print("Kurtosis:", kurtosis(data))


✅Output>>>
Skewness: 0.8482177333018041
Kurtosis: -0.14983918636679595

'''

# %%
#Q8.Generate a dataset and demonstrate positive and negative skewness.
'''
import numpy as np
import matplotlib.pyplot as plt

# Positive Skew
pos_skew = np.random.exponential(scale=2, size=1000)

# Negative Skew
neg_skew = -np.random.exponential(scale=2, size=1000)

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.hist(pos_skew, bins=30, color='blue', edgecolor='black')
plt.title('Positive Skew')

plt.subplot(1,2,2)
plt.hist(neg_skew, bins=30, color='red', edgecolor='black')
plt.title('Negative Skew')

plt.show()
'''

# %%
#Q9.Write a Python script to calculate covariance between two datasets.
'''
import numpy as np

x = [1, 2, 3, 4, 5]
y = [2, 4, 5, 4, 5]

cov_matrix = np.cov(x, y)
print("Covariance Matrix:\n", cov_matrix)
'''

# %%
#Q10.Write a Python script to calculate the correlation coefficient between two datasets.
'''
import numpy as np

x = [1, 2, 3, 4, 5]
y = [2, 4, 5, 4, 5]

correlation = np.corrcoef(x, y)
print("Correlation Coefficient Matrix:\n", correlation)
'''

# %%
#Q11.Create a scatter plot to visualize the relationship between two variables.
'''
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 5, 4, 5]

plt.scatter(x, y)
plt.title('Scatter Plot')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.show()
'''

# %%
#Q12.Implement and compare simple random sampling and systematic sampling.
'''
import random

# Simple Random Sampling
data = list(range(1, 101))
simple_random_sample = random.sample(data, 10)
print("Simple Random Sample:", simple_random_sample)

# Systematic Sampling
k = 10
systematic_sample = [data[i] for i in range(0, len(data), k)]
print("Systematic Sample:", systematic_sample)
'''

# %%
#Q13.Calculate the mean, median, and mode of grouped data.
'''
import statistics

data = [10, 10, 20, 20, 20, 30, 30, 40, 50, 50]

mean = statistics.mean(data)
median = statistics.median(data)
mode = statistics.mode(data)

print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)
'''

# %%
#Q14.Simulate data using Python and calculate its central tendency and dispersion.
'''
import numpy as np

data = np.random.randint(1, 100, 50)

mean = np.mean(data)
median = np.median(data)
std_dev = np.std(data)

print("Mean:", mean)
print("Median:", median)
print("Standard Deviation:", std_dev)
'''

# %%
#Q15.Use NumPy or pandas to summarize a dataset’s descriptive statistics.
'''
import pandas as pd

data = {'Marks': [50, 60, 70, 80, 90]}
df = pd.DataFrame(data)

summary = df.describe()
print(summary)

✅Output>>>
          Marks
count   5.000000
mean   70.000000
std    15.811388
min    50.000000
25%    60.000000
50%    70.000000
75%    80.000000
max    90.000000
'''

# %%
#Q16.Plot a boxplot to understand the spread and identify outliers.
'''
import matplotlib.pyplot as plt

data = [50, 60, 70, 80, 90, 100, 120]

plt.boxplot(data)
plt.title('Boxplot')
plt.show()
'''

# %%
#Q17Calculate the interquartile range (IQR) of a dataset?
'''
import numpy as np

data = [50, 60, 70, 80, 90, 100, 120]

Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1

print("Interquartile Range (IQR):", IQR)

✅Output>>>

Interquartile Range (IQR): 30.0
'''

# %%
#Q18.Implement Z-score normalization and explain its significance.
'''
from scipy.stats import zscore

data = [50, 60, 70, 80, 90, 100, 120]
z_scores = zscore(data)

print("Z-scores:", z_scores)

#Explanation:

Z-score normalization helps to standardize data (mean = 0, std = 1).

Useful when comparing different datasets.
'''

# %%
#Q19.Compare two datasets using their standard deviations.
'''
import numpy as np

data1 = [10, 20, 30, 40, 50]
data2 = [5, 15, 25, 35, 100]

std1 = np.std(data1)
std2 = np.std(data2)

print("Standard Deviation of Data1:", std1)
print("Standard Deviation of Data2:", std2)

✅Output>>>
Standard Deviation of Data1: 14.142135623730951
Standard Deviation of Data2: 32.01562118716424

#Conclusion:
Data2 is more spread out (higher variability).
'''

# %%
#20.Write a Python program to visualize covariance using a heatmap.
'''
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = {'A': [1, 2, 3, 4, 5], 'B': [2, 4, 5, 4, 5]}
df = pd.DataFrame(data)

cov_matrix = df.cov()

sns.heatmap(cov_matrix, annot=True, cmap="coolwarm")
plt.title('Covariance Heatmap')
plt.show()
'''

# %%
#21.Use seaborn to create a correlation matrix for a dataset.
'''
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = {'A': [1, 2, 3, 4, 5], 'B': [2, 4, 5, 4, 5]}
df = pd.DataFrame(data)

correlation_matrix = df.corr()

sns.heatmap(correlation_matrix, annot=True, cmap="YlGnBu")
plt.title('Correlation Matrix')
plt.show()
'''

# %%
#Q22.Generate a dataset and implement both variance and standard deviation computations.
'''
import numpy as np

data = np.random.randint(1, 100, 20)

variance = np.var(data)
std_dev = np.std(data)

print("Data:", data)
print("Variance:", variance)
print("Standard Deviation:", std_dev)
'''

# %%
#Q23.Visualize skewness and kurtosis using Python libraries like matplotlib or seaborn.
'''
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import skew, kurtosis
import numpy as np

data = np.random.normal(0, 1, 1000)

sns.histplot(data, kde=True)
plt.title('Distribution with Skewness and Kurtosis')
plt.show()

print("Skewness:", skew(data))
print("Kurtosis:", kurtosis(data))
'''

# %%
#24.Implement the Pearson and Spearman correlation coefficients for a dataset.
'''
from scipy.stats import pearsonr, spearmanr

x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 4, 6]

# Pearson Correlation
pearson_corr, _ = pearsonr(x, y)
print('Pearson Correlation:', pearson_corr)

# Spearman Correlation
spearman_corr, _ = spearmanr(x, y)
print('Spearman Correlation:', spearman_corr)

✅Output>>>

Pearson Correlation: 0.9
Spearman Correlation: 0.9
'''
